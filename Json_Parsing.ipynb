# %%
import json
import pandas as pd
import os
import re
path = 'C:/Users/USER/DA_Projects/NASA Asteroids Classification/raw_dataset/Raw_Data_JSON/Raw_Data'
df = []
tot_elem_count=0;
files = os.listdir(path)
for file in files:
    date = file.split('e')[1].split('.')[0]
    tot_path = path+'/'+file  
    #parse json file into a python dictionary
    with open(tot_path, 'r') as f:
        d = json.loads(f.read())
    elem_count = d['element_count']
    tot_elem_count += elem_count
    if elem_count > 0:
        newd = d['near_earth_objects'][date];
        for i in newd:
            i['close_approach_data'] = i['close_approach_data'][0]
        df = df + newd;
#normalize semi-structured json data
data = pd.json_normalize(df)
train = pd.DataFrame.from_dict(data, orient='columns')
train
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)
#      neo_reference_id                name  \
# 0             3703080         (2014 YW34)
# 1             3723955          (2015 NK3)
# 2             2446862  446862 (2001 VB76)
# 3             3092506          (2001 WJ4)
# 4             3514799         (2010 FH81)
# ...               ...                 ...
# 4682          3759007         (2016 RQ17)
# 4683          3759295         (2016 RN20)
# 4684          3759714          (2016 SE1)
# 4685          3759720          (2016 SV1)
# 4686          3772978        (2017 FE101)
#
#                                        nasa_jpl_url  absolute_magnitude_h  \
# 0     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3703080                21.600
# 1     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3723955                21.300
# 2     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2446862                20.300
# 3     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092506                27.400
# 4     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3514799                21.600
# ...                                             ...                   ...
# 4682  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3759007                23.900
# 4683  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3759295                28.200
# 4684  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3759714                22.700
# 4685  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3759720                21.800
# 4686  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3772978                19.109
#
#       is_potentially_hazardous_asteroid  \
# 0                                  True
# 1                                 False
# 2                                  True
# 3                                 False
# 4                                  True
# ...                                 ...
# 4682                              False
# 4683                              False
# 4684                              False
# 4685                              False
# 4686                              False
#
#                                              links.self  \
# 0     https://api.nasa.gov/neo/rest/v1/neo/3703080?a...
# 1     https://api.nasa.gov/neo/rest/v1/neo/3723955?a...
# 2     https://api.nasa.gov/neo/rest/v1/neo/2446862?a...
# 3     https://api.nasa.gov/neo/rest/v1/neo/3092506?a...
# 4     https://api.nasa.gov/neo/rest/v1/neo/3514799?a...
# ...                                                 ...
# 4682  https://api.nasa.gov/neo/rest/v1/neo/3759007?a...
# 4683  https://api.nasa.gov/neo/rest/v1/neo/3759295?a...
# 4684  https://api.nasa.gov/neo/rest/v1/neo/3759714?a...
# 4685  https://api.nasa.gov/neo/rest/v1/neo/3759720?a...
# 4686  https://api.nasa.gov/neo/rest/v1/neo/3772978?a...
#
#       estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                              0.127220
# 1                                              0.146068
# 2                                              0.231502
# 3                                              0.008801
# 4                                              0.127220
# ...                                                 ...
# 4682                                           0.044112
# 4683                                           0.006089
# 4684                                           0.076658
# 4685                                           0.116026
# 4686                                           0.400641
#
#       estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                              0.284472
# 1                                              0.326618
# 2                                              0.517654
# 3                                              0.019681
# 4                                              0.284472
# ...                                                 ...
# 4682                                           0.098637
# 4683                                           0.013616
# 4684                                           0.171412
# 4685                                           0.259442
# 4686                                           0.895860
#
#       estimated_diameter.meters.estimated_diameter_min  \
# 0                                           127.219879
# 1                                           146.067964
# 2                                           231.502122
# 3                                             8.801465
# 4                                           127.219879
# ...                                                ...
# 4682                                         44.111820
# 4683                                          6.089126
# 4684                                         76.657557
# 4685                                        116.025908
# 4686                                        400.640618
#
#       estimated_diameter.meters.estimated_diameter_max  ...  \
# 0                                           284.472297  ...
# 1                                           326.617897  ...
# 2                                           517.654482  ...
# 3                                            19.680675  ...
# 4                                           284.472297  ...
# ...                                                ...  ...
# 4682                                         98.637028  ...
# 4683                                         13.615700  ...
# 4684                                        171.411509  ...
# 4685                                        259.441818  ...
# 4686                                        895.859655  ...
#
#       orbital_data.inclination  orbital_data.ascending_node_longitude  \
# 0            6.025981287138329                      314.3739134134077
# 1            28.41299637199041                      136.7172416568082
# 2            4.237961002947924                      259.4759789450263
# 3            7.905894348125122                      57.17326613388248
# 4            16.79338165999116                      84.62930679460825
# ...                        ...                                    ...
# 4682          39.8804910829102                      164.1833052860387
# 4683         5.360248787502739                      345.2252302789072
# 4684         4.405467043030848                      37.02646769456528
# 4685         21.08024392659721                      163.8029095254848
# 4686         53.57492250368969                       187.642183340195
#
#       orbital_data.orbital_period  orbital_data.perihelion_distance  \
# 0                609.599786407648                  .808258932678493
# 1               425.8692942066788                 .7181996160227876
# 2                643.580228077368                  .950790956866954
# 3               514.0821403654488                 .9839015669723666
# 4                495.597820944911                 .9676866361064762
# ...                           ...                               ...
# 4682               457.1799843926                 .7415579555133625
# 4683            407.1857671217926                 .9964342678688585
# 4684            690.0542788076862                 .9657603480910034
# 4685            662.0483427912479                 1.185467298615728
# 4686            653.6790976660942                 .8761102025429766
#
#      orbital_data.perihelion_argument  orbital_data.aphelion_distance  \
# 0                   57.25746987539545               2.005763672747459
# 1                   313.0919748302692               1.497352292852652
# 2                   248.4150381128607               1.966856672082667
# 3                   18.70770087172089               1.527904212254787
# 4                   158.2635960713293               1.483542837130177
# ...                               ...                             ...
# 4682                276.3956972002647                1.58129927018655
# 4683                42.11106385534595               1.153834616727024
# 4684                274.6927123513995               2.090707839014692
# 4685                180.3460898857109               1.787733081222486
# 4686                222.4366879064714               2.071980060689654
#
#      orbital_data.perihelion_time orbital_data.mean_anomaly  \
# 0            2458161.641720486318         264.8375332988031
# 1            2457794.969431284686         173.7411119891742
# 2            2458120.467548905740         292.8936537794408
# 3            2457902.337433852940         68.74100661777578
# 4            2457814.455148689195         135.1421326756292
# ...                           ...                       ...
# 4682         2457708.228252311514         304.3060245387305
# 4683         2458087.616506017017         282.9787858553869
# 4684         2458300.479730754856         203.5011471005674
# 4685         2458288.261214860106         203.5249653931955
# 4686         2458318.586741341018         184.8204244382007
#
#      orbital_data.mean_motion orbital_data.equinox
# 0           .5905513880204395                J2000
# 1           .8453297875598617                J2000
# 2           .5593708201314143                J2000
# 3           .7002771964497434                J2000
# 4           .7263954456329549                J2000
# ...                       ...                  ...
# 4682        .7874360477051257                J2000
# 4683        .8841173465975324                J2000
# 4684        .5216980910864401                J2000
# 4685        .5437669377468897                J2000
# 4686        .5507289452658797                J2000
#
# [4687 rows x 42 columns]

# %%
#saving pandas dataframe as a csv file
train.to_csv('C:/Users/USER/DA_Projects/NASA-Asteroids-Classification/Asteroids.csv', index = False)
